# %% [markdown]
# # 기본 train 파일 호출
# - 기본적인 train 파일의 성능을 확인하기 위해 제작.
# - test_pearson() score: 0.81
# - base, 80% 증가, MSE score, 3 times: 0.9
# - 추가 500 step warmup: 0.91

# %% [markdown]
# ## Train

# %%
# !ls
# !python code/base_model/base_2.py --train=True --model_name="klue/roberta-large" --sweeps_cnt=1
# Out:
# '0.8, base'   data			        new_dataset.csv   wget-log
#  Readme.md    lightning_logs		        output.csv	  wget-log.1
#  code	      model_bat_16_lr_1e-05.pt	        output_1.csv
#  cudnn	      model_bat_32_lr_1e-05_wm-100.pt   wandb
# Namespace(batch_size=16, dev_path='./data/dev.csv', entity_name='nlp-10', learning_rate=1e-05, max_epoch=3, model_name='klue/roberta-large', predict_path='./data/test.csv', project_name='sts', shuffle=True, sweeps_cnt='3', test_path='./data/dev.csv', train='True', train_path='./data/train.csv')
# Train mode
# Create sweep with ID: cvai53xr
# Sweep URL: https://wandb.ai/nlp-10/sts/sweeps/cvai53xr
# wandb: Agent Starting Run: txzhn5iv with config:
# wandb: 	batch_size: 32
# wandb: 	lr: 1e-05
# wandb: 	max_epoch: 5
# wandb: 	warmup_step: 1
# wandb: Currently logged in as: kms7530 (nlp-10). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.14.2
# ...

# %% [markdown]
# ## Test

# %%
# !ls
# !python code/base_model/base_2.py --train=False --model_name="klue/roberta-large"
# Out:
# '0.8, base'   data			        new_dataset.csv   wget-log
#  Readme.md    lightning_logs		        output.csv	  wget-log.1
#  code	      model_bat_16_lr_1e-05.pt	        output_1.csv
#  cudnn	      model_bat_32_lr_1e-05_wm-100.pt   wandb
# Namespace(batch_size=16, dev_path='./data/dev.csv', entity_name='nlp-10', learning_rate=1e-05, max_epoch=3, model_name='klue/roberta-large', predict_path='./data/test.csv', project_name='sts', shuffle=True, sweeps_cnt=5, test_path='./data/dev.csv', train='False', train_path='./data/train.csv')
# Inference mode
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ...
